# %% [markdown]
# ## Separando os Dados(Treino e Teste) e verificando dados faltantes

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Ignore Warning(Avisos)
import warnings

warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', 100)

# %%
# Carregando os dados
churn = pd.read_csv('../Data/Data_Transformedv22.0.csv')

# Amostra
churn.head()
# Out:
#             SeniorCitizen  Partner  Dependents  tenure  InternetService  \
# 7590-VHVEG              0        1           0       1                1
# 5575-GNVDE              0        0           0      34                1
# 3668-QPYBK              0        0           0       2                1
# 7795-CFOCW              0        0           0      45                1
# 9237-HQITU              0        0           0       2                2
#
#             Contract  PaperlessBilling  PaymentMethod  MonthlyCharges  \
# 7590-VHVEG         0                 1              1           29.85
# 5575-GNVDE         2                 0              0           56.95
# 3668-QPYBK         0                 1              0           53.85
# 7795-CFOCW         2                 0              2           42.30
# 9237-HQITU         0                 1              1           70.70
#
#             TotalCharges  Churn  OnlineSecurity_No internet service  \
# 7590-VHVEG         29.85      0                                 0.0
# 5575-GNVDE       1936.30      0                                 0.0
# 3668-QPYBK        107.70      1                                 0.0
# 7795-CFOCW       1903.50      0                                 0.0
# 9237-HQITU        141.40      1                                 0.0
#
#             OnlineSecurity_Yes  OnlineBackup_No internet service  \
# 7590-VHVEG                 0.0                               0.0
# 5575-GNVDE                 1.0                               0.0
# 3668-QPYBK                 1.0                               0.0
# 7795-CFOCW                 1.0                               0.0
# 9237-HQITU                 0.0                               0.0
#
#             OnlineBackup_Yes  DeviceProtection_No internet service  \
# 7590-VHVEG               1.0                                   0.0
# 5575-GNVDE               0.0                                   0.0
# 3668-QPYBK               1.0                                   0.0
# 7795-CFOCW               0.0                                   0.0
# 9237-HQITU               0.0                                   0.0
#
#             DeviceProtection_Yes  TechSupport_No internet service  \
# 7590-VHVEG                   0.0                              0.0
# 5575-GNVDE                   1.0                              0.0
# 3668-QPYBK                   0.0                              0.0
# 7795-CFOCW                   1.0                              0.0
# 9237-HQITU                   0.0                              0.0
#
#             TechSupport_Yes  StreamingTV_No internet service  StreamingTV_Yes  \
# 7590-VHVEG              0.0                              0.0              0.0
# 5575-GNVDE              0.0                              0.0              0.0
# 3668-QPYBK              0.0                              0.0              0.0
# 7795-CFOCW              1.0                              0.0              0.0
# 9237-HQITU              0.0                              0.0              0.0
#
#             StreamingMovies_No internet service  StreamingMovies_Yes
# 7590-VHVEG                                  0.0                  0.0
# 5575-GNVDE                                  0.0                  0.0
# 3668-QPYBK                                  0.0                  0.0
# 7795-CFOCW                                  0.0                  0.0
# 9237-HQITU                                  0.0                  0.0

# %%
# Separando as variáveis preditoras da variável target -> coluna 'Churn'
X = churn.drop(['Churn'], axis=1)
y = churn[['Churn']]

# Separando os dados em treino e teste
X_treino, X_teste, y_treino, y_teste = train_test_split(X,
                                                        y,
                                                        test_size=.2,
                                                        random_state=42)

X_treino.shape, X_teste.shape, y_treino.shape, y_teste.shape
# Out:
# ((5634, 22), (1409, 22), (5634, 1), (1409, 1))

# %%
# Salvando
X_treino.to_csv('../Data/x_treino.csv', index_label=False)
X_teste.to_csv('../Data/x_teste.csv', index_label=False)
y_treino.to_csv('../Data/y_treino.csv', index_label=False)
y_teste.to_csv('../Data/y_teste.csv', index_label=False)
